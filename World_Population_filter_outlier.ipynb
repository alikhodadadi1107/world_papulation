# %% [markdown]
# # world papulation

# %% [markdown]
# # step for EDA :
#
#  1. import libraries
#
#  2. load data --> df = pd.read_csv( ' file.csv ' )
#
#  3. data understanding/knowing:
#
#     3.1. df.shape
#
#     3.2. df.head() , df.tail() , df.sample()
#
#     3.3. df.info() --> dtype , null
#
#     3.4. df.describe() --> statsrical , overview
#
#     3.5. numerical / categorical = df.select_dtypes(include/exclude = " numerical " / " object "
#
#     3.6. Feature relations : correlation , Mutual information , statstical test
#
# 4. remove duplicate
#
# 5. null handeling
#
# 6. Skewness handeling
#
# 7. outlier handeling
#
# 8. filter data for advances analysis
#
# 9. scale the numeric data
#
# 10. Encode categorical data
#
# 11. feature engineering:
#
#     11.1. Dimensionality Reduction ( e.g. PCA , tSNE ,UMAP ) ---> unsupervised learning
#
#     11.2. Manual featuring

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('world_population.csv')

# %%
df.head()
# Out:
#    Rank CCA3 Country/Territory           Capital Continent  2022 Population  \
# 0    36  AFG       Afghanistan             Kabul      Asia         41128771
# 1   138  ALB           Albania            Tirana    Europe          2842321
# 2    34  DZA           Algeria           Algiers    Africa         44903225
# 3   213  ASM    American Samoa         Pago Pago   Oceania            44273
# 4   203  AND           Andorra  Andorra la Vella    Europe            79824
#
#    2020 Population  2015 Population  2010 Population  2000 Population  \
# 0         38972230         33753499         28189672         19542982
# 1          2866849          2882481          2913399          3182021
# 2         43451666         39543154         35856344         30774621
# 3            46189            51368            54849            58230
# 4            77700            71746            71519            66097
#
#    1990 Population  1980 Population  1970 Population  Area (km²)  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country/Territory            234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              234 non-null    int64
#  6   2020 Population              234 non-null    int64
#  7   2015 Population              234 non-null    int64
#  8   2010 Population              234 non-null    int64
#  9   2000 Population              234 non-null    int64
#  10  1990 Population              234 non-null    int64
#  11  1980 Population              234 non-null    int64
#  12  1970 Population              234 non-null    int64
# ...

# %%
df.describe().T # transpose
# Out:
#                              count          mean           std       min  \
# Rank                         234.0  1.175000e+02  6.769417e+01    1.0000
# 2022 Population              234.0  3.407441e+07  1.367664e+08  510.0000
# 2020 Population              234.0  3.350107e+07  1.355899e+08  520.0000
# 2015 Population              234.0  3.172996e+07  1.304050e+08  564.0000
# 2010 Population              234.0  2.984524e+07  1.242185e+08  596.0000
# 2000 Population              234.0  2.626947e+07  1.116982e+08  651.0000
# 1990 Population              234.0  2.271022e+07  9.783217e+07  700.0000
# 1980 Population              234.0  1.898462e+07  8.178519e+07  733.0000
# 1970 Population              234.0  1.578691e+07  6.779509e+07  752.0000
# Area (km²)                   234.0  5.814494e+05  1.761841e+06    1.0000
# Density (per km²)            234.0  4.521270e+02  2.066122e+03    0.0261
# Growth Rate                  234.0  1.009577e+00  1.338498e-02    0.9120
# ...

# %%
df.sort_values(by='2022 Population', ascending=False).head(5)
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41        1425887337       1424929781       1393715448       1348191368
# 92        1417173173       1396387127       1322866505       1240613620
# 221        338289857        335942003        324607776        311182845
# 93         275501339        271857970        259091970        244016173
# 156        235824862        227196741        210969298        194454498
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
numerical_cols = df.select_dtypes(include='number').columns
numerical_cols
# Out:
# Index(['Rank', '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
#cat_cols ---> categorical_cols
#cat_cols = df.select_dtypes(exclude = 'number').columns
#cat_cols = df.select_dtypes(include='float').columns
#cat_cols = df.select_dtypes(include='int').columns

cat_cols = df.select_dtypes(include='object').columns
cat_cols
# Out:
# Index(['CCA3', 'Country/Territory', 'Capital', 'Continent'], dtype='object')

# %%
df[numerical_cols].corr()
# Out:
#                                  Rank  2022 Population  2020 Population  \
# Rank                         1.000000        -0.358361        -0.355854
# 2022 Population             -0.358361         1.000000         0.999946
# 2020 Population             -0.355854         0.999946         1.000000
# 2015 Population             -0.351222         0.999490         0.999763
# 2010 Population             -0.347461         0.998629         0.999105
# 2000 Population             -0.341057         0.994605         0.995583
# 1990 Population             -0.336152         0.987228         0.988724
# 1980 Population             -0.335246         0.980285         0.982121
# 1970 Population             -0.335379         0.973162         0.975254
# Area (km²)                  -0.383774         0.453411         0.454993
# Density (per km²)            0.129436        -0.027618        -0.027358
# Growth Rate                 -0.224561        -0.020863        -0.025116
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df[numerical_cols].corr() , annot = True)
plt.show()

# %% [markdown]
# # Remove Duplicate

# %%
# check duplicate
df.duplicated().sum()
# Out:
# 0

# %%
# remove duplicate
df = df.drop_duplicates(inplace=True)

# %% [markdown]
# # null handeling

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country/Territory              0
# Capital                        0
# Continent                      0
# 2022 Population                0
# 2020 Population                0
# 2015 Population                0
# 2010 Population                0
# 2000 Population                0
# 1990 Population                0
# 1980 Population                0
# 1970 Population                0
# Area (km²)                     0
# Density (per km²)              0
# Growth Rate                    0
# World Population Percentage    0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
#  null_handeling ---> row removal
df1 = df.dropna() # rows
df1.isnull().sum().sum()

# column removal ---> not recommended
df2 = df.dropna(axis=1) # columns
df2.isnull().sum().sum()

# %%
# Impute nulls , constant value | numerical ---> mean,median   |  categorical --> mode |  KNN imputer | algoritm ML impute

#constant value
df4 = df.fillna(0)
df4.isnull().sum().sum()

#numerical
df5 = df[numerical_cols].fillna(df[numerical_cols].mean())
df5.isnull().sum().sum()

# categorical
df6 = df[cat_cols].fillna(df[cat_cols].moode())
df6.isnull().sum().sum()

# KNN for numeric
from sklearn.import KNNImputer
knnimp = KNNImputer(n_neighbors = 3)
df7 = knnimp.fit_transform(df[numerical_cols])
df7.isnull().sum().sum()
pd.DataFrame(df7 , columns= numerical_cols).isnull().sum()

df8 = pd.concat((df[cat_cols] ,pd.DataFrame(df7)))
df.isnull().sum()

# %% [markdown]
# # Skewness handeling

# %%
# skewness analysis

def visualize_numerical_distributions(df, exclude_columns='id'):

    # Set up the figure for multiple subplots
    num_cols = 3  # Number of columns for the subplot grid
    num_rows = (len(numerical_cols) + num_cols - 1) // num_cols  # Calculate number of rows needed

    fig, axes = plt.subplots(num_rows, num_cols, figsize=(18, 5 * num_rows))
    fig.suptitle('Distribution of Numerical Features', fontsize=16)

    # Flatten axes array for easy iteration
    axes = axes.flatten()

    # Iterate over each numerical column and create a histogram with KDE
    for i, col in enumerate(numerical_cols):
        sns.histplot(df[col], kde=True, ax=axes[i], color="skyblue", element="step", stat="density")
        axes[i].set_title(f'Distribution of {col}', fontsize=14)
        axes[i].set_xlabel(col, fontsize=12)
        axes[i].set_ylabel('Density', fontsize=12)

    # Remove unused axes
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    # Adjust layout
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Adjust the main title space
    plt.show()


visualize_numerical_distributions(df)

# %%
df["2022 Population"].skew()
# Out:
# 9.151204821104248

# %%
df['Growth Rate'].skew()
# Out:
# -1.1016696427888626

# %%
from scipy import stats

def robust_skewness_handler(df, threshold=2.0):
    transformed_df = df.copy()
    transformation_dict = {}

    for col in df.select_dtypes(include=[np.number]).columns:
        data = df[col].dropna()
        skewness = data.skew()

        if abs(skewness) > threshold:
            print(f"Handling skewness for {col} (skewness: {skewness:.2f})")

            # Handle zero-inflated or near-zero-inflated data
            if (data == 0).sum() / len(data) > 0.1:  # If more than 10% zeros
                non_zero = data[data != 0]
                if len(non_zero) > 0:
                    log_transform = np.log1p(non_zero)
                    transformed_df.loc[data != 0, col] = log_transform
                    transformation_dict[col] = ('log1p', 'zero-inflated')
                    print(f"  Applied Log1p to non-zero values for {col}")
                continue

            # Try Box-Cox transformation
            min_val = data.min()
            if min_val <= 0:
                shift = abs(min_val) + 1
                shifted_data = data + shift
            else:
                shifted_data = data

            try:
                transformed_data, lambda_param = stats.boxcox(shifted_data)
                transformed_df[col] = transformed_data
                transformation_dict[col] = ('box-cox', lambda_param)
                print(f"  Applied Box-Cox to {col} (lambda: {lambda_param:.2f})")
            except:
                # If Box-Cox fails, try other transformations
                if skewness > 0:  # Right-skewed
                    if data.max() / data.min() > 1000:  # Very large range
                        transformed_df[col] = np.log1p(data)
                        transformation_dict[col] = ('log1p', None)
                        print(f"  Applied Log1p to {col}")
                    else:
                        transformed_df[col] = np.sqrt(data)
                        transformation_dict[col] = ('sqrt', None)
                        print(f"  Applied Square Root to {col}")
                else:  # Left-skewed
                    transformed_df[col] = data ** 2
                    transformation_dict[col] = ('square', None)
                    print(f"  Applied Square to {col}")

    return transformed_df, transformation_dict

# Example usage:
transformed_df, transformations = robust_skewness_handler(df)
visualize_numerical_distributions(transformed_df)
# Out:
# Handling skewness for 2022 Population (skewness: 9.15)
#   Applied Box-Cox to 2022 Population (lambda: 0.09)
# Handling skewness for 2020 Population (skewness: 9.18)
#   Applied Box-Cox to 2020 Population (lambda: 0.09)
# Handling skewness for 2015 Population (skewness: 9.24)
#   Applied Box-Cox to 2015 Population (lambda: 0.09)
# Handling skewness for 2010 Population (skewness: 9.29)
#   Applied Box-Cox to 2010 Population (lambda: 0.09)
# Handling skewness for 2000 Population (skewness: 9.42)
#   Applied Box-Cox to 2000 Population (lambda: 0.08)
# Handling skewness for 1990 Population (skewness: 9.61)
#   Applied Box-Cox to 1990 Population (lambda: 0.08)
# Handling skewness for 1980 Population (skewness: 9.66)
#   Applied Box-Cox to 1980 Population (lambda: 0.08)
# Handling skewness for 1970 Population (skewness: 9.65)
#   Applied Box-Cox to 1970 Population (lambda: 0.07)
# Handling skewness for Area (km²) (skewness: 6.08)
#   Applied Box-Cox to Area (km²) (lambda: 0.10)
# ...

# %% [markdown]
# # outlier handeling

# %%
plt .figure(figsize=(10,5))
df.boxplot()
plt.xticks(rotation=90)
plt.show()

# %%
def calculate_outliers_percentage(df):
    outlier_counts = {}
    for column in df.select_dtypes(include=['number']).columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Calculate outliers
        outliers = df[(df[column] < lower_bound) | (df[column] > upper_bound)]
        outlier_counts[column] = len(outliers)

    # Print the percentage of outliers for each column
    for column in outlier_counts:
        percentage = (outlier_counts[column] / len(df)) * 100
        print(f"Percentage of outliers in {column}: {percentage:.2f}%")

# Example usage:
calculate_outliers_percentage(df)
# Out:
# Percentage of outliers in Rank: 0.00%
# Percentage of outliers in 2022 Population: 10.68%
# Percentage of outliers in 2020 Population: 11.11%
# Percentage of outliers in 2015 Population: 11.54%
# Percentage of outliers in 2010 Population: 11.11%
# Percentage of outliers in 2000 Population: 12.39%
# Percentage of outliers in 1990 Population: 13.25%
# Percentage of outliers in 1980 Population: 13.68%
# Percentage of outliers in 1970 Population: 12.39%
# Percentage of outliers in Area (km²): 11.97%
# Percentage of outliers in Density (per km²): 9.40%
# Percentage of outliers in Growth Rate: 1.28%
# Percentage of outliers in World Population Percentage: 10.68%

# %%
def handle_outliers(df):
    for column in numerical_cols:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Capping
        df[column] = df[column].clip(lower=lower_bound, upper=upper_bound)

    return df

# Apply to both training and test datasets
df = handle_outliers(df)

# %%
calculate_outliers_percentage(df)
# Out:
# Percentage of outliers in Rank: 0.00%
# Percentage of outliers in 2022 Population: 0.00%
# Percentage of outliers in 2020 Population: 0.00%
# Percentage of outliers in 2015 Population: 0.00%
# Percentage of outliers in 2010 Population: 0.00%
# Percentage of outliers in 2000 Population: 0.00%
# Percentage of outliers in 1990 Population: 0.00%
# Percentage of outliers in 1980 Population: 0.00%
# Percentage of outliers in 1970 Population: 0.00%
# Percentage of outliers in Area (km²): 0.00%
# Percentage of outliers in Density (per km²): 0.00%
# Percentage of outliers in Growth Rate: 0.00%
# Percentage of outliers in World Population Percentage: 0.00%

# %%
# Group by 'Continent' and aggregate population data
population_agg = df.groupby('Continent')['2022 Population'].agg(['sum', 'mean', 'median', 'std']).reset_index()

# Rename columns for clarity
population_agg.columns = ['Continent', 'Total Population', 'Mean Population', 'Median Population', 'Population Std Dev']

# Display the aggregated table
population_agg.sort_values(by='Total Population', ascending=False)

# %% [markdown]
# # Filter data

# %%
# loc ----> row and columns filtering

df.loc[:'2022 Population']
# Out:
#      Rank CCA3 Country/Territory           Capital      Continent  \
# 0      36  AFG       Afghanistan             Kabul           Asia
# 1     138  ALB           Albania            Tirana         Europe
# 2      34  DZA           Algeria           Algiers         Africa
# 3     213  ASM    American Samoa         Pago Pago        Oceania
# 4     203  AND           Andorra  Andorra la Vella         Europe
# ..    ...  ...               ...               ...            ...
# 198    32  SDN             Sudan          Khartoum         Africa
# 199   170  SUR          Suriname        Paramaribo  South America
# 200    87  SWE            Sweden         Stockholm         Europe
# 201   101  CHE       Switzerland              Bern         Europe
# 202    60  SYR             Syria          Damascus           Asia
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0         38972230       33753499.0       28189672.0
# ...

# %%
df.loc[df['2022 Population']> 3e8 , '2022 Population']
# Out:
# 41     1425887337
# 92     1417173173
# 221     338289857
# Name: 2022 Population, dtype: int64

# %%
df.loc[df['2022 Population']> 3e8 , ['2022 Population' , 'Country/Territory']].sort_values(by = '2022 Population' , ascending = False)
# Out:
#      2022 Population Country/Territory
# 41        1425887337             China
# 92        1417173173             India
# 221        338289857     United States

# %%
df.columns
# Out:
# Index(['Rank', 'CCA3', 'Country/Territory', 'Capital', 'Continent',
#        '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population', '1990 Population',
#        '1980 Population', '1970 Population', 'Area (km²)', 'Density (per km²)',
#        'Growth Rate', 'World Population Percentage'],
#       dtype='object')

# %%
df.loc[(df['2022 Population']> 2e8 ) & (df['Area (km²)']> 5e3) , ['2022 Population' , 'Country/Territory'] ]
# Out:
#      2022 Population Country/Territory
# 27         215313498            Brazil
# 41        1425887337             China
# 92        1417173173             India
# 93         275501339         Indonesia
# 149        218541212           Nigeria
# 156        235824862          Pakistan
# 221        338289857     United States

# %%
# iloc ---> row and colummn filtering

# %%
# boolean condition

df[df['Continent']  == 'Asia']
# Out:
#      Rank CCA3     Country/Territory              Capital Continent  \
# 0      36  AFG           Afghanistan                Kabul      Asia
# 9     140  ARM               Armenia              Yerevan      Asia
# 13     91  AZE            Azerbaijan                 Baku      Asia
# 15    154  BHR               Bahrain               Manama      Asia
# 16      8  BGD            Bangladesh                Dhaka      Asia
# 23    165  BTN                Bhutan              Thimphu      Asia
# 29    175  BRN                Brunei  Bandar Seri Begawan      Asia
# 33     73  KHM              Cambodia           Phnom Penh      Asia
# 41      1  CHN                 China              Beijing      Asia
# 73    131  GEO               Georgia              Tbilisi      Asia
# 89    104  HKG             Hong Kong            Hong Kong      Asia
# 92      2  IND                 India            New Delhi      Asia
# 93      4  IDN             Indonesia              Jakarta      Asia
# ...

# %%
df[(df['Continent']  == 'Asia') & (df['2022 Population']<df['2020 Population'] )]
# Out:
#      Rank CCA3 Country/Territory      Capital Continent  2022 Population  \
# 9     140  ARM           Armenia      Yerevan      Asia          2780469
# 15    154  BHR           Bahrain       Manama      Asia          1472233
# 73    131  GEO           Georgia      Tbilisi      Asia          3744385
# 89    104  HKG         Hong Kong    Hong Kong      Asia          7488865
# 102    11  JPN             Japan        Tokyo      Asia        123951692
# 108   129  KWT            Kuwait  Kuwait City      Asia          4268873
# 112   119  LBN           Lebanon       Beirut      Asia          5489739
# 167   143  QAT             Qatar         Doha      Asia          2695122
# 194    29  KOR       South Korea        Seoul      Asia         51815810
#
#      2020 Population  2015 Population  2010 Population  2000 Population  \
# 9            2805608          2878595          2946293          3168523
# 15           1477469          1362142          1213645           711442
# ...
